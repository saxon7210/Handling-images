# %%
import pandas as pd

# %%
data1=pd.read_csv(r"C:\Users\LENOVO\Videos\train (2).csv",on_bad_lines="skip",delimiter=";")

# %%
data1.head(2)
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Palestinians switch off Christmas lights in Be...
# 1           1  China says Trump call with Taiwan president wo...
#
#                                                 text  label
# 0  RAMALLAH, West Bank (Reuters) - Palestinians s...      1
# 1  BEIJING (Reuters) - U.S. President-elect Donal...      1

# %%
data1c=data1.copy()

# %%
data1c.head(2)
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Palestinians switch off Christmas lights in Be...
# 1           1  China says Trump call with Taiwan president wo...
#
#                                                 text  label
# 0  RAMALLAH, West Bank (Reuters) - Palestinians s...      1
# 1  BEIJING (Reuters) - U.S. President-elect Donal...      1

# %%
simple_eda(data1c[1:300],"text")
# Out:
# have both lower and upper case
# have tags
# have urls
# have emials
# have mentions
# have digit
# have punc

# %%
# 4 problem statemtn

# %%
final_data=pre_proce(data1c[1:300],"text")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15808\3488132214.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[coln]=data[coln].apply(lambda x:emoji.demojize(x,delimiters=('', '')))
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15808\3488132214.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[coln]=data[coln].str.lower()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15808\3488132214.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[coln]=data[coln].apply(lambda x:re.sub("<.*?>"," ",x))
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15808\3488132214.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[coln]=data[coln].apply(lambda x:re.sub("https?://\S+"," ",x))
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15808\3488132214.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[coln]=data[coln].apply(lambda x:re.sub("\S+@\S+"," ",x))
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15808\3488132214.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[coln]=data[coln].apply(lambda x:re.sub("\B[@#]\S+"," ",x))
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15808\3488132214.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[coln]=data[coln].apply(lambda x:re.sub("\d"," ",x))
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15808\3488132214.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[coln]=data[coln].apply(lambda x:re.sub(r"\b[0-9]{4}\/[0-9]{1,2}\/[0-9]{1,2}\b"," ",x))
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15808\3488132214.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[coln]=data[coln].apply(lambda x:re.sub(r"\b[0-9]{1,2}\/[0-9]{1,2}\/[0-9]{4}\b"," ",x))
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15808\3488132214.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[coln]=data[coln].apply(lambda x:contractions.fix(x))
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15808\3488132214.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[coln]=data[coln].apply(lambda x:re.sub('[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]'," ",x))

# %%
final_data
# Out:
#      Unnamed: 0                                              title  \
# 1             1  China says Trump call with Taiwan president wo...
# 2             2   FAIL! The Trump Organization’s Credit Score W...
# 3             3  Zimbabwe military chief's China trip was norma...
# 4             4  THE MOST UNCOURAGEOUS PRESIDENT EVER Receives ...
# 5             5  Suspected Boko Haram suicide bombers kill at l...
# ..          ...                                                ...
# 295         295   Activist Trolls Republicans For Their Phony C...
# 296         296   Trump’s Legal Team Directly Contradicts Him O...
# 297         297  Hungary prosecutors probe accounts of oppositi...
# 298         298  Iowa kicks off 2016 U.S. presidential race wit...
# 299         299  Whirlpool's washer war is balancing act for Trump
#
#                                                   text  label
# 1    beijing  reuters    you s  president elect don...      1
# 2    while the controversy over trump s personal ta...      0
# 3    beijing  reuters    a trip to beijing last wee...      1
# 4    there has never been a more uncourageous perso...      0
# 5    bauchi  nigeria  reuters    suspected boko har...      1
# ..                                                 ...    ...
# 295  the united states just experienced its worst m...      0
# 296  despite his tweets  apparently trump isn t bei...      0
# 297  budapest  reuters    hungarian prosecutors sai...      1
# 298  des moines  iowa  reuters    the long and some...      1
# 299  clyde  ohio  reuters    in the middle of whirl...      1
#
# [299 rows x 4 columns]

# %%
simple_eda(final_data[1:300],"text")
# Out:
# have both lower and upper case

# %%
def pre_proce(data,coln,case="lower",tags=True,urls=True,emails=True,mentions=True,digits=True,dates=True,emojii=True,contractionsss=True,stopwordss=True,infl="stem",stemms="porter",punch=True):
    import re
    import emoji
    import contractions
    from nltk.corpus import stopwords
    from nltk.tokenize import word_tokenize
    from nltk.stem import PorterStemmer,LancasterStemmer,SnowballStemmer,WordNetLemmatizer
    ps=PorterStemmer()
    ls=LancasterStemmer()
    ss=SnowballStemmer(language="english")
    wl=WordNetLemmatizer()
    
    #stopwords creation
    stp=stopwords.words("english")
    stp.remove("not")
    
    acro={"gm":"good morning","gn":"good night","omg":"o my god"}
    
    #emoji
    if emojii==True:
        data[coln]=data[coln].apply(lambda x:emoji.demojize(x,delimiters=('', '')))
    else:
        pass
    
    # case
    if case=="lower":
        data[coln]=data[coln].str.lower()
    elif case=="upper":
        data[coln]=data[coln].str.upper()
    else:
        pass
    
    #tags
    if tags==True:
        data[coln]=data[coln].apply(lambda x:re.sub("<.*?>"," ",x))
    else:
        pass
    
    #urls
    if urls==True:
        data[coln]=data[coln].apply(lambda x:re.sub("https?://\S+"," ",x))
    else:
        pass
    
    #emails
    if emails==True:
        data[coln]=data[coln].apply(lambda x:re.sub("\S+@\S+"," ",x))
    else:
        pass
    
    #mentions
    if mentions==True:
        data[coln]=data[coln].apply(lambda x:re.sub("\B[@#]\S+"," ",x))
    else:
        pass
    
    #digits
    if digits==True:
        data[coln]=data[coln].apply(lambda x:re.sub("\d"," ",x))
    else:
        pass
    
    #dates
    if dates==True:
        data[coln]=data[coln].apply(lambda x:re.sub(r"\b[0-9]{4}\/[0-9]{1,2}\/[0-9]{1,2}\b"," ",x))
        data[coln]=data[coln].apply(lambda x:re.sub(r"\b[0-9]{1,2}\/[0-9]{1,2}\/[0-9]{4}\b"," ",x))
    else:
        pass
    
    #contractionsss
    if contractionsss==True:
        data[coln]=data[coln].apply(lambda x:contractions.fix(x))
    else:
        pass
    #stopwordss
    if stopwordss==True:
        l2=[]
        for doc in data[coln]:# looping through documents
            l1=[]
            for word in word_tokenize(doc): # looping throug words
                if word not in stp:# checking word is present in stp
                    l1.append(word)
                else:
                    pass

            l2.append([" ".join(l1)])
        data[coln]=l2
    else:
        pass
    # stemming and lemmatization
    if infl=="stem":
        l3=[]
        for doc in data[coln]:
            l4=[]
            print(data[coln].head())
            for word1 in word_tokenize(doc):
                print(word1)
                if stemms=="porter":
                    l4.append(ps.stem(word))
                elif stemms=="snow":
                    l4.append(ss.stem(word))
                elif stemms=="lanc":
                    l4.append(ls.stem(word))
            l3.append([" ".join(l4)])
        data[coln]=l3
      
    elif infl=="lemma":
        l5=[]
        for doc in data[coln]:
            l6=[]
            for word in word_tokenize(doc):
                l6.append(wl.lemmatize(word))
            l5.append([" ".join(l6)])
            
        data[coln]=l5
    
    # punc
    
    if punch==True:
        data[coln]=data[coln].apply(lambda x:re.sub('[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]'," ",x))
    else:
        pass
    
    return data

# %%
def pre_proce(data,coln,case="lower",tags=True,urls=True,emails=True,mentions=True,digits=True,dates=True,emojii=True,contractionsss=True,stopwordss=True,infl="stem",stemms="porter",punch=True):
    import re
    import emoji
    import contractions
    from nltk.corpus import stopwords
    from nltk.tokenize import word_tokenize
    from nltk.stem import PorterStemmer,LancasterStemmer,SnowballStemmer,WordNetLemmatizer
    ps=PorterStemmer()
    ls=LancasterStemmer()
    ss=SnowballStemmer(language="english")
    wl=WordNetLemmatizer()
    
    #stopwords creation
    stp=stopwords.words("english")
    stp.remove("not")
    
    acro={"gm":"good morning","gn":"good night","omg":"o my god"}
    
    #emoji
    if emojii==True:
        data[coln]=data[coln].apply(lambda x:emoji.demojize(x,delimiters=('', '')))
    else:
        pass
    
    # case
    if case=="lower":
        data[coln]=data[coln].str.lower()
    elif case=="upper":
        data[coln]=data[coln].str.upper()
    else:
        pass
    
    #tags
    if tags==True:
        data[coln]=data[coln].apply(lambda x:re.sub("<.*?>"," ",x))
    else:
        pass
    
    #urls
    if urls==True:
        data[coln]=data[coln].apply(lambda x:re.sub("https?://\S+"," ",x))
    else:
        pass
    
    #emails
    if emails==True:
        data[coln]=data[coln].apply(lambda x:re.sub("\S+@\S+"," ",x))
    else:
        pass
    
    #mentions
    if mentions==True:
        data[coln]=data[coln].apply(lambda x:re.sub("\B[@#]\S+"," ",x))
    else:
        pass
    
    #digits
    if digits==True:
        data[coln]=data[coln].apply(lambda x:re.sub("\d"," ",x))
    else:
        pass
    
    #dates
    if dates==True:
        data[coln]=data[coln].apply(lambda x:re.sub(r"\b[0-9]{4}\/[0-9]{1,2}\/[0-9]{1,2}\b"," ",x))
        data[coln]=data[coln].apply(lambda x:re.sub(r"\b[0-9]{1,2}\/[0-9]{1,2}\/[0-9]{4}\b"," ",x))
    else:
        pass
    
    #contractionsss
    if contractionsss==True:
        data[coln]=data[coln].apply(lambda x:contractions.fix(x))
    else:
        pass
    
    
    if punch==True:
        data[coln]=data[coln].apply(lambda x:re.sub('[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]'," ",x))
    else:
        pass
    
    return data

# %%
data1=pd.read_csv(r"C:\Users\LENOVO\Videos\train (2).csv",on_bad_lines="skip",delimiter=";")
